# %%
from google.colab import drive

drive.mount('/content/drive')

# %cd drive/MyDrive/CGDC/NLI
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/CGDC/NLI

# %%
relations_to_templates = {
    "date_of_death": "died on",
    "significant_person": {
        "Person": {"Person": "communicated with"},
        "Organisation": {"Person": "is made up of"}
    },
    "partnership_with": "collaborated with",
    "place_of_birth": "was born in",
    "date_of_birth": "was born on",
    "spouse": "married to",
    "location": "happened in",
    "operating_area": "operated in",
    "participant_in": "participated in",
    "occupation": "worked as a",
    "member_of": "was a member of",
    "location_in": "is located in",
    "notable_work": {
        "Person": {
            "Location": "built",
            "Misc": "created"
        },
        "Organisation": {
            "Misc": "created"
        }
    },
    "inception": "was created on",
    "point_in_time": {
        "Misc": {"Date": "happened on"},
        "Location": {"Date": "as of"}
    },
    "work_location": "worked in",
    "residence": "lived in",
    "affiliation": "was connected or linked to",
    "employer": "worked for",
    "depicts": "shows"
}

# %%
import csv

with open('nli_util/mapping_of_relation_types.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    header = next(reader)
    rows = []
    for row in reader:
        if row[0] == '':
            break
        rows.append(row)

entity_types = set()
for row in rows:
    entity_types.add(row[0])
    entity_types.add(row[3])


possible_relations = {}
for relation_1 in entity_types:
    possible_relations[relation_1] = {}
    for relation_2 in entity_types:
        possible_relations[relation_1][relation_2] = []

for row in rows:
    head_entity_type = row[0]
    tail_entity_type = row[3]
    pair_relation = row[5].replace(" ", "_")
    if pair_relation[-1] == "_":
      pair_relation = pair_relation[:-1]
    if pair_relation == 'located_in/on_physical_feature':
      pair_relation = 'location_in'

    possible_relations[head_entity_type][tail_entity_type].append(pair_relation)
    relations.add(pair_relation)

for relation_1 in entity_types:
  for relation_2 in entity_types:
    pass
    #print(f"For {relation_1} -> {relation_2}")
    #print(possible_relations[relation_1][relation_2])
    #print()

# %%
f = open("nli_util/relation_types_priorities.txt", "r")
relation_types_priorities = {}
for line in f:
  relation_types, *relations = line.split()
  if relation_types == "Person-Misc" or relation_types == "Misc-Location":
    continue
  else:
    relations_list = []
    for relation in relations:
      if relation != ">":
        relations_list.append(relation)
    relation_types_priorities[relation_types] = relations_list

# %% [markdown]
# #Experiments

# %%
# !pip install transformers
# !pip install sentence_transformers

from transformers import T5Tokenizer, T5ForConditionalGeneration, BartForSequenceClassification, BartTokenizer, pipeline
from sentence_transformers import CrossEncoder
import json
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, precision_score, recall_score
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Collecting sentence_transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.42.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.3.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 12.7 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence_transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 sentence_transformers-3.0.1

# %%
def softmax(x):
    return(np.exp(x)/np.exp(x).sum())

def predict(model_name, model, tokenizer, premise, hypothesis_list, current_relations, current_templates, head, tail, head_type, tail_type, obj_for_current_sample):
  if model_name == "deberta":
    most_likely_label = ("", 0)

    labels = ["contradiction", "entailment", "neutral"]
    obj_for_current_sample["hypotheses"] = []

    scores = model.predict([(premise, curr_hypothesis) for curr_hypothesis in hypothesis_list])
    for idx, score in enumerate(scores):
      # (contradiction, entailment, neutral)
      probs = softmax(score)
      if probs[1] > probs[0] and probs[1] > probs[2]:
        if probs[1] > most_likely_label[1]:
          most_likely_label = (current_relations[idx], probs[1])
      obj_for_current_sample["hypotheses"].append({"hypothesis": hypothesis_list[idx], "probabilities": {labels[i] : float(probs[i]) for i in range(len(labels))}})

    final_prediction = most_likely_label[0] if most_likely_label[1] > 0.40 else "NOTA"
    obj_for_current_sample["prediction"] = final_prediction

    return final_prediction

  elif model_name == "bart":
    labels = ["contradiction", "neutral", "entailment"]
    most_likely_label = ("", 0)
    obj_for_current_sample["hypotheses"] = []

    for idx, hypothesis in enumerate(hypothesis_list):
      tokens = tokenizer(premise, hypothesis, return_tensors="pt")
      outputs = model(**tokens)
      probs = outputs.logits.softmax(dim=1)
      predicted_label = labels[int(probs.argmax(axis=1))]
      if predicted_label == "entailment":
        if probs[0][2] > most_likely_label[1]:
          most_likely_label = (current_relations[idx], probs[0][2])
      obj_for_current_sample["hypotheses"].append({"hypothesis": hypothesis, "probabilities": {labels[i] : float(probs[0][i]) for i in range(len(labels))}})

    final_prediction = most_likely_label[0] if most_likely_label[1] > 0.40 else "NOTA"
    obj_for_current_sample["prediction"] = final_prediction

    return final_prediction
  elif model_name == "t5-xxl":
    input_list = [f"premise: {premise} hypothesis: {curr_hypothesis}" for curr_hypothesis in hypothesis_list]

    # Tokenize and generate predictions
    inputs = tokenizer(input_list, return_tensors="pt", padding=True)
    output_sequences = model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        do_sample=False,  # disable sampling to test if batching affects output
    )

    predictions = tokenizer.batch_decode(output_sequences, skip_special_tokens=True)
    number_of_positive_predictions = predictions.count("1")
    if number_of_positive_predictions == 0:
      final_prediction = "NOTA"
    elif number_of_positive_predictions == 1:
      final_prediction = current_relations[predictions.index("1")]
    else:
      candidate_labels = [current_relations[i] for i in range(len(current_relations)) if predictions[i] == "1"]
      final_prediction = choose_final_label(head_type, tail_type, candidate_labels)

    obj_for_current_sample["hypotheses"] = [{"hypothesis": hypothesis_list[idx], "prediction": predictions[idx]} for idx in range(len(hypothesis_list))]
    obj_for_current_sample["prediction"] = final_prediction
    return final_prediction
  else:
    print("Wrong name for model supplied.")
    return


def get_current_templates(current_relations, head_type, tail_type):
  current_templates = []
  for relation in current_relations:
    if isinstance(relations_to_templates[relation], dict):
      current_templates.append(relations_to_templates[relation][head_type][tail_type])
    else:
      current_templates.append(relations_to_templates[relation])
  return current_templates

def get_current_model(model_name):
  if model_name == "deberta":
    tokenizer = None
    model = CrossEncoder('cross-encoder/nli-deberta-v3-large')
  elif model_name == "bart":
    tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-mnli")
    model = BartForSequenceClassification.from_pretrained("facebook/bart-large-mnli")
  elif model_name == "t5-xxl":
    tokenizer = T5Tokenizer.from_pretrained("google/t5_xxl_true_nli_mixture")
    model = T5ForConditionalGeneration.from_pretrained("google/t5_xxl_true_nli_mixture")
  else:
    print("Incorrect name for model.")
    tokenizer = None
    model = None
  return (tokenizer, model)


def macro_weighted_averages(data):
  labels_of_interest_sample_counter = sum([data["results"]["label_wise"][key]["samples_per_class"] if key != "NOTA" else 0 for key in data["results"]["label_wise"].keys()])
  nota_sample_counter = data["results"]["label_wise"]["NOTA"]["samples_per_class"]

  weighted_macro_f1_score_labels_of_interest = sum([data["results"]["label_wise"][key]["samples_per_class"] * data["results"]["label_wise"][key]["f1_score"] if key != "NOTA" else 0 for key in data["results"]["label_wise"].keys()]) / labels_of_interest_sample_counter
  weighted_macro_recall_labels_of_interest = sum([data["results"]["label_wise"][key]["samples_per_class"] * data["results"]["label_wise"][key]["recall"] if key != "NOTA" else 0 for key in data["results"]["label_wise"].keys()]) / labels_of_interest_sample_counter
  weighted_macro_precision_score_labels_of_interest = sum([data["results"]["label_wise"][key]["samples_per_class"] * data["results"]["label_wise"][key]["precision"] if key != "NOTA" else 0 for key in data["results"]["label_wise"].keys()]) / labels_of_interest_sample_counter
  weighted_macro_f1_score_nota = data["results"]["label_wise"]["NOTA"]["f1_score"]
  weighted_macro_recall_score_nota = data["results"]["label_wise"]["NOTA"]["recall"]
  weighted_macro_precision_score_nota = data["results"]["label_wise"]["NOTA"]["precision"]

  print(f"Non-NOTA Precision: {weighted_macro_precision_score_labels_of_interest}")
  print(f"Non-NOTA Recall: {weighted_macro_recall_labels_of_interest}")
  print(f"Non-NOTA F1-score: {weighted_macro_f1_score_labels_of_interest}")
  print()
  print(f"NOTA Precision: {weighted_macro_precision_score_nota}")
  print(f"NOTA Recall: {weighted_macro_recall_score_nota}")
  print(f"NOTA F1-score: {weighted_macro_f1_score_nota}")
  print()
  print()

  return {
      "non_NOTA_macro_weighted_precision": weighted_macro_precision_score_labels_of_interest,
      "non_NOTA_macro_weighted_recall": weighted_macro_recall_labels_of_interest,
      "non_NOTA_macro_weighted_f1_score": weighted_macro_f1_score_labels_of_interest,
      "NOTA_macro_weighted_precision": weighted_macro_precision_score_nota,
      "NOTA_macro_weighted_recall": weighted_macro_recall_score_nota,
      "NOTA_macro_weighted_f1_score": weighted_macro_f1_score_nota,
}

def choose_final_label(head_type, tail_type, candidate_labels):

  relation_type = f"{head_type}-{tail_type}"
  if relation_type == "Person-Misc":
    return "notable_work"
  elif relation_type == "Misc-Location":
    return "location"
  else:
    labels_indexes = [relation_types_priorities[relation_type].index(label) for label in candidate_labels]
    index_min = min(range(len(labels_indexes)), key=labels_indexes.__getitem__)
    final_prediction = candidate_labels[index_min]
    return final_prediction

def run_experiment(model_name, dataset_path):
  (tokenizer, model) = get_current_model(model_name)

  with open(dataset_path) as infile:
    data = json.load(infile)

  samples_counter = 0
  green_samples_counter = 0
  red_samples_counter = 0
  nota_green_samples_counter = 0
  nota_red_samples_counter = 0
  results = {"data": {},
             "results": {
                 "label_wise": {},
                 "overall": {}
             }}

  for key_index, key in enumerate(list(data.keys())):
    results["data"][key] = []
    print(f"Key {key_index + 1} / {len(list(data.keys())) - 1}")
    for obj_index, obj in enumerate(data[key]):
      print(f"Sample {obj_index+1}/{len(data[key])}")
      premise = obj['sample']
      head = obj['h'][0]
      tail = obj['t'][0]
      head_type = obj['h'][2]
      tail_type = obj['t'][2]
      golden_standard = key
      obj_for_current_sample = {"premise": premise,
                                "head": obj['h'],
                                "tail": obj['t']}

      current_relations = possible_relations[head_type][tail_type]
      if len(current_relations) != 0:
        current_templates = get_current_templates(current_relations, head_type, tail_type)

        hypothesis_list = [f"{head} {x} {tail}" for x in current_templates]

        final_prediction = predict(model_name, model, tokenizer, premise, hypothesis_list, current_relations, current_templates, head, tail, head_type, tail_type, obj_for_current_sample)
      else:
        obj_for_current_sample["hypotheses"] = []
        obj_for_current_sample["prediction"] = "NOTA"
        final_prediction = "NOTA"

      results["data"][key].append(obj_for_current_sample)

      if key == "NOTA":
        if final_prediction == golden_standard:
          nota_green_samples_counter += 1
        else:
          nota_red_samples_counter += 1
      else:
        if final_prediction == golden_standard:
          green_samples_counter += 1
        else:
          red_samples_counter += 1

      samples_counter += 1

    results["results"]["label_wise"][key] = {
        "samples_per_class": obj_index + 1
    }

  print(f"Green samples count: {green_samples_counter}")
  print(f"Red samples count: {red_samples_counter}")
  print(f"NOTA green samples count: {nota_green_samples_counter}")
  print(f"NOTA red samples count: {nota_red_samples_counter}")

  indexes = []
  precisions = []
  recalls = []
  f1_scores = []
  number_of_samples_from_class = []

  for label_to_evaluate in results["data"].keys():
    keywise_one_hot_encoded_vector = []
    predictions_for_current_label = []
    indexes.append(label_to_evaluate)
    for key in results["data"].keys():
      keywise_one_hot_encoded_vector += [1 if label_to_evaluate == key else 0 for i in range(results["results"]["label_wise"][key]["samples_per_class"])]
      predictions_for_current_label += [1 if sample["prediction"] == label_to_evaluate else 0 for sample in results["data"][key]]

    key_precision = precision_score(keywise_one_hot_encoded_vector, predictions_for_current_label, zero_division=0)
    key_recall = recall_score(keywise_one_hot_encoded_vector, predictions_for_current_label, zero_division=0)
    key_f1_score = f1_score(keywise_one_hot_encoded_vector, predictions_for_current_label, zero_division=0)
    samples_per_class = results["results"]["label_wise"][label_to_evaluate]['samples_per_class']
    precisions.append(key_precision)
    recalls.append(key_recall)
    f1_scores.append(key_f1_score)
    number_of_samples_from_class.append(samples_per_class)

    results['results']['label_wise'][label_to_evaluate] = {"precision": key_precision,
                                                      "recall": key_recall,
                                                      "f1_score": key_f1_score,
                                                      "samples_per_class": samples_per_class}


  non_NOTA_macro_weighted_precision, \
  non_NOTA_macro_weighted_recall, \
  non_NOTA_macro_weighted_f1_score, \
  NOTA_macro_weighted_precision, \
  NOTA_macro_weighted_recall, \
  NOTA_macro_weighted_f1_score = macro_weighted_averages(results).values()

  results["results"]["overall"] = {
        "correctly_classified_labels_of_interest": green_samples_counter,
        "incorrectly_classified_labels_of_interest": red_samples_counter,
        "correctly_classified_NOTA_samples": nota_green_samples_counter,
        "incorrectly_classified_NOTA_samples": nota_red_samples_counter,
        "non_NOTA_macro_weighted_precision": non_NOTA_macro_weighted_precision,
        "non_NOTA_macro_weighted_recall": non_NOTA_macro_weighted_recall,
        "non_NOTA_macro_weighted_f1_score": non_NOTA_macro_weighted_f1_score,
        "NOTA_macro_weighted_precision": NOTA_macro_weighted_precision,
        "NOTA_macro_weighted_recall": NOTA_macro_weighted_recall,
        "NOTA_macro_weighted_f1_score": NOTA_macro_weighted_f1_score
  }

  with open(f'nli_results/results_{model_name}.json', 'w') as fp:
    json.dump(results, fp)

  df = pd.DataFrame({"precision": precisions,
                    "recall": recalls,
                    "f1_score": f1_scores,
                    "num of samples": number_of_samples_from_class},
                    index=(indexes)).sort_values('f1_score', ascending=False)

  return df

# %%
df = run_experiment("deberta", 'nli_util/CGDC_3.0_updated.json')

# %% [markdown]
# #Ensemble testing

# %%
def predict_ensemble(models, tokenizers, premise, hypothesis_list, current_relations, current_templates, head, tail, head_type, tail_type, obj_for_current_sample):
  bart_object = {}
  deberta_object = {}
  t5_object = {}

  bart_prediction = predict("bart", models["bart"], tokenizers["bart"], premise, hypothesis_list, current_relations, current_templates, head, tail, head_type, tail_type, bart_object)
  deberta_prediction = predict("deberta", models["deberta"], tokenizers["deberta"], premise, hypothesis_list, current_relations, current_templates, head, tail, head_type, tail_type, deberta_object)
  t5_prediction = predict("t5-xxl", models["t5-xxl"], tokenizers["t5-xxl"], premise, hypothesis_list, current_relations, current_templates, head, tail, head_type, tail_type, t5_object)

  predictions = {}
  predictions[bart_prediction] = 1 if bart_prediction not in predictions else predictions[bart_prediction] + 1
  predictions[deberta_prediction] = 1 if deberta_prediction not in predictions else predictions[deberta_prediction] + 1
  predictions[t5_prediction] = 1 if t5_prediction not in predictions else predictions[t5_prediction] + 1

  if len(predictions.keys()) == 1:
    final_prediction = list(predictions.keys())[0]
  elif len(predictions.keys()) == 2:
    final_prediction = ""
    max_counter = 0
    for candidate_label in predictions.keys():
      if predictions[candidate_label] > max_counter:
        final_prediction = candidate_label
        max_counter = predictions[candidate_label]
  else:
    candidate_labels = [label for label in list(predictions.keys()) if label != "NOTA"]
    final_prediction = choose_final_label(head_type, tail_type, candidate_labels)

  obj_for_current_sample |= {"bart_predictions": bart_object,
                             "deberta_predictions": deberta_object,
                             "t5_predictions": t5_object,
                             "prediction": final_prediction}

  return final_prediction

def run_experiment_ensemble(dataset_path):
  tokenizer_bart, model_bart = get_current_model("bart")
  tokenizer_deberta, model_deberta = get_current_model("deberta")
  tokenizer_t5_xxl, model_t5_xxl = get_current_model("t5-xxl")

  models = {"bart": model_bart,
            "deberta": model_deberta,
            "t5-xxl": model_t5_xxl}

  tokenizers = {"bart": tokenizer_bart,
                "deberta": tokenizer_deberta,
                "t5-xxl": tokenizer_t5_xxl}

  with open(dataset_path) as infile:
    data = json.load(infile)

  samples_counter = 0
  green_samples_counter = 0
  red_samples_counter = 0
  nota_green_samples_counter = 0
  nota_red_samples_counter = 0
  results = {"data": {},
             "results": {
                 "label_wise": {},
                 "overall": {}
             }}

  for key_index, key in enumerate(list(data.keys())):
    results["data"][key] = []
    print(f"Key {key_index + 1} / {len(list(data.keys())) - 1}")
    for obj_index, obj in enumerate(data[key]):
      print(f"Sample {obj_index+1}/{len(data[key])}")
      premise = obj['sample']
      head = obj['h'][0]
      tail = obj['t'][0]
      head_type = obj['h'][2]
      tail_type = obj['t'][2]
      golden_standard = key
      obj_for_current_sample = {"premise": premise,
                                "head": obj['h'],
                                "tail": obj['t']}

      current_relations = possible_relations[head_type][tail_type]
      if len(current_relations) != 0:
        current_templates = get_current_templates(current_relations, head_type, tail_type)

        hypothesis_list = [f"{head} {x} {tail}" for x in current_templates]

        final_prediction = predict_ensemble(models, tokenizers, premise, hypothesis_list, current_relations, current_templates, head, tail, head_type, tail_type, obj_for_current_sample)
      else:
        obj_for_current_sample["hypotheses"] = []
        obj_for_current_sample["prediction"] = "NOTA"
        final_prediction = "NOTA"

      results["data"][key].append(obj_for_current_sample)

      if key == "NOTA":
        if final_prediction == golden_standard:
          nota_green_samples_counter += 1
        else:
          nota_red_samples_counter += 1
      else:
        if final_prediction == golden_standard:
          green_samples_counter += 1
        else:
          red_samples_counter += 1

      samples_counter += 1

    results["results"]["label_wise"][key] = {
        "samples_per_class": obj_index + 1
    }

  print(f"Green samples count: {green_samples_counter}")
  print(f"Red samples count: {red_samples_counter}")
  print(f"NOTA green samples count: {nota_green_samples_counter}")
  print(f"NOTA red samples count: {nota_red_samples_counter}")

  indexes = []
  precisions = []
  recalls = []
  f1_scores = []
  number_of_samples_from_class = []

  for label_to_evaluate in results["data"].keys():
    keywise_one_hot_encoded_vector = []
    predictions_for_current_label = []
    indexes.append(label_to_evaluate)
    for key in results["data"].keys():
      keywise_one_hot_encoded_vector += [1 if label_to_evaluate == key else 0 for i in range(results["results"]["label_wise"][key]["samples_per_class"])]
      predictions_for_current_label += [1 if sample["prediction"] == label_to_evaluate else 0 for sample in results["data"][key]]

    key_precision = precision_score(keywise_one_hot_encoded_vector, predictions_for_current_label, zero_division=0)
    key_recall = recall_score(keywise_one_hot_encoded_vector, predictions_for_current_label, zero_division=0)
    key_f1_score = f1_score(keywise_one_hot_encoded_vector, predictions_for_current_label, zero_division=0)
    samples_per_class = results["results"]["label_wise"][label_to_evaluate]['samples_per_class']
    precisions.append(key_precision)
    recalls.append(key_recall)
    f1_scores.append(key_f1_score)
    number_of_samples_from_class.append(samples_per_class)

    results['results']['label_wise'][label_to_evaluate] = {"precision": key_precision,
                                                      "recall": key_recall,
                                                      "f1_score": key_f1_score,
                                                      "samples_per_class": samples_per_class}


  non_NOTA_macro_weighted_precision, \
  non_NOTA_macro_weighted_recall, \
  non_NOTA_macro_weighted_f1_score, \
  NOTA_macro_weighted_precision, \
  NOTA_macro_weighted_recall, \
  NOTA_macro_weighted_f1_score = macro_weighted_averages(results).values()

  results["results"]["overall"] = {
        "correctly_classified_labels_of_interest": green_samples_counter,
        "incorrectly_classified_labels_of_interest": red_samples_counter,
        "correctly_classified_NOTA_samples": nota_green_samples_counter,
        "incorrectly_classified_NOTA_samples": nota_red_samples_counter,
        "non_NOTA_macro_weighted_precision": non_NOTA_macro_weighted_precision,
        "non_NOTA_macro_weighted_recall": non_NOTA_macro_weighted_recall,
        "non_NOTA_macro_weighted_f1_score": non_NOTA_macro_weighted_f1_score,
        "NOTA_macro_weighted_precision": NOTA_macro_weighted_precision,
        "NOTA_macro_weighted_recall": NOTA_macro_weighted_recall,
        "NOTA_macro_weighted_f1_score": NOTA_macro_weighted_f1_score
  }

  with open(f'results_ensemble_demoREAL.json', 'w') as fp:
    json.dump(results, fp)

  df = pd.DataFrame({"precision": precisions,
                    "recall": recalls,
                    "f1_score": f1_scores,
                    "num of samples": number_of_samples_from_class},
                    index=(indexes)).sort_values('f1_score', ascending=False)

  return df

# %%
df_ensemble = run_experiment_ensemble('nli_util/CGDC_3.0_updated.json')

# %% [markdown]
# #KG Creation

# %%
with open('results_ensemble.json') as f:
  data = json.load(f)

entity_counter = {}
entities = {}
relations = set()
for key in data['data'].keys():
  for sample in data['data'][key]:
    if sample['prediction'] != "NOTA":
      if sample['head'][1] != "N/A":
        entity_counter[sample['head'][1]] = 1 if sample['head'][1] not in entity_counter else entity_counter[sample['head'][1]] + 1
        entities[sample['head'][1]] = {
            "name": sample['head'][0],
            "type": sample['head'][2]
        }
      if sample['tail'][1] != "N/A":
        entity_counter[sample['tail'][1]] = 1 if sample['tail'][1] not in entity_counter else entity_counter[sample['tail'][1]] + 1
        entities[sample['tail'][1]] = {
            "name": sample['tail'][0],
            "type": sample['tail'][2]
        }
      if sample['head'][1] != "N/A" and sample['tail'][1] != "N/A":
        relations.add(f"{sample['head'][1]}#{sample['tail'][1]}#{sample['prediction']}")

def sortt(a):
  return a[1]

stats = [(k, v) for k, v in entity_counter.items()]
stats.sort(reverse=True, key=sortt)

# %%
# Function to generate Cypher code for creating relations
def generate_cypher_relations(entities, relationships):
    cypher_statements = ["CREATE"]
    for id in entities.keys():
        cypher = f'({id}:{entities[id]["type"]} {{ID: "{id}", name: "{entities[id]["name"]}"}}),'
        cypher_statements.append(cypher)
    for relationship in relationships:
        head_id, tail_id, relation = relationship.split("#")
        cypher = f"({head_id})-[:{relation}]-> ({tail_id}),"
        cypher_statements.append(cypher)
    return "\n".join(cypher_statements)

# Generate and print the Cypher code
cypher = generate_cypher_relations(entities, relations)

print(cypher)
# Out:
# CREATE
# (Q104822257:Location {ID: "Q104822257", name: "Promenade Penzance"}),
# (Q17644344:Misc {ID: "Q17644344", name: "Bleu Bridge inscribed stone"}),
# (Q5617932:Location {ID: "Q5617932", name: "Gulval"}),
# (Q30524253:Location {ID: "Q30524253", name: "King's Hall"}),
# (Q22677638:Misc {ID: "Q22677638", name: "Ned and donkey, Pool Park"}),
# (Q496368:Location {ID: "Q496368", name: "Wrexham"}),
# (Q20594046:Misc {ID: "Q20594046", name: "Cofiwch Dryweryn"}),
# (Q881062:Location {ID: "Q881062", name: "Blaenau Ffestiniog"}),
# (Q2745177:Misc {ID: "Q2745177", name: "National Eisteddfod"}),
# (Q1186888:Location {ID: "Q1186888", name: "Denbigh"}),
# (Q748065:Location {ID: "Q748065", name: "Caerphilly"}),
# (Q207176:Location {ID: "Q207176", name: "Monmouthshire"}),
# (Q675460:Location {ID: "Q675460", name: "Machynlleth"}),
# (Q2233618:Location {ID: "Q2233618", name: "Llanrwst"}),
# (Q66362702:Location {ID: "Q66362702", name: "London Road Presbyterian Church"}),
# (Q25:Location {ID: "Q25", name: "Wales"}),
# (Q29492351:Location {ID: "Q29492351", name: "Penwenallt"}),
# (Q3139233:Location {ID: "Q3139233", name: "National Botanic Garden of Wales"}),
# (Q996492:Location {ID: "Q996492", name: "Llandudno"}),
# (Q669171:Location {ID: "Q669171", name: "Newtown"}),
# (Q990103:Location {ID: "Q990103", name: "Haverfordwest"}),
# (Q670265:Misc {ID: "Q670265", name: "Eisteddfod"}),
# (Q1428848:Location {ID: "Q1428848", name: "Flint"}),
# (Q13443285:Location {ID: "Q13443285", name: "Newlyn Town"}),
# (Q7993516:Location {ID: "Q7993516", name: "Wherrytown"}),
# (Q89035834:Location {ID: "Q89035834", name: "B3315"}),
# (Q652930:Location {ID: "Q652930", name: "St Buryan"}),
# (Q360724:Person {ID: "Q360724", name: "Stanhope Forbes RA"}),
# (Q16998883:Organisation {ID: "Q16998883", name: "Newlyn School of Art"}),
# (Q977864:Location {ID: "Q977864", name: "Twelveheads"}),
# (Q180803:Location {ID: "Q180803", name: "Truro"}),
# (Q23148:Location {ID: "Q23148", name: "Cornwall"}),
# (Q100164652:Misc {ID: "Q100164652", name: "1936 Housing Act"}),
# (Q104395394:Organisation {ID: "Q104395394", name: "Penzance Council"}),
# (Q208209:Location {ID: "Q208209", name: "Penzance"}),
# (Q116887767:Location {ID: "Q116887767", name: "Green Market"}),
# (Q5413890:Organisation {ID: "Q5413890", name: "HSBC Bank"}),
# (Q2146298:Location {ID: "Q2146298", name: "Alverton"}),
# (Q17530818:Location {ID: "Q17530818", name: "Alverne Restaurant and Lounge"}),
# (Q1067943:Organisation {ID: "Q1067943", name: "F.R.I.B.A."}),
# (Q26515392:Location {ID: "Q26515392", name: "Gothic House"}),
# (Q24662603:Location {ID: "Q24662603", name: "Jubilee Pool"}),
# (Q1025780:Location {ID: "Q1025780", name: "Polperro"}),
# (Q26596711:Location {ID: "Q26596711", name: "The House on the Props"}),
# (Q1286223:Location {ID: "Q1286223", name: "south Wales"}),
# (Q3404663:Location {ID: "Q3404663", name: "Abercynon"}),
# (Q3406657:Location {ID: "Q3406657", name: "Penydarren"}),
# (Q116874592:Location {ID: "Q116874592", name: "Redruth parish church"}),
# (Q5691488:Location {ID: "Q5691488", name: "Heamoor"}),
# (Q939838:Location {ID: "Q939838", name: "Sevenoaks"}),
# (Q97581503:Person {ID: "Q97581503", name: "Henry Albert Browne"}),
# (Q23156:Location {ID: "Q23156", name: "Devon"}),
# (Q209055:Location {ID: "Q209055", name: "Torquay"}),
# (Q34217:Location {ID: "Q34217", name: "Oxford"}),
# (Q7812993:Location {ID: "Q7812993", name: "Toft"}),
# (Q23090:Location {ID: "Q23090", name: "lincolsshire"}),
# (Q779603:Location {ID: "Q779603", name: "Market Rasen"}),
# (Q222595:Organisation {ID: "Q222595", name: "British Army"}),
# (Q668:Location {ID: "Q668", name: "India"}),
# (Q1348:Location {ID: "Q1348", name: "Kolkata"}),
# (Q80338:Location {ID: "Q80338", name: "Bengal"}),
# (Q75960697:Person {ID: "Q75960697", name: "Horace"}),
# (Q836:Location {ID: "Q836", name: "Burma"}),
# (Q142:Location {ID: "Q142", name: "France"}),
# (Q33959:Location {ID: "Q33959", name: "Nice"}),
# (Q7902126:Location {ID: "Q7902126", name: "Usselby"}),
# (Q500101:Organisation {ID: "Q500101", name: "the Wonder Stuff"}),
# (Q11790927:Location {ID: "Q11790927", name: "Newport Centre"}),
# (Q4039563:Organisation {ID: "Q4039563", name: "Goldie Lookin Chain"}),
# (Q16897354:Location {ID: "Q16897354", name: "TJ's in the Square"}),
# (Q1479031:Organisation {ID: "Q1479031", name: "Shelac"}),
# (Q219772:Person {ID: "Q219772", name: "PJ Harvey"}),
# (Q784824:Location {ID: "Q784824", name: "Pembroke Dock"}),
# (Q3094812:Location {ID: "Q3094812", name: "Wales"}),
# (Q22890:Location {ID: "Q22890", name: "Ireland"}),
# (Q1939963:Location {ID: "Q1939963", name: "Neyland"}),
# (Q843251:Location {ID: "Q843251", name: "Great Western Railway"}),
# (Q24204847:Location {ID: "Q24204847", name: "Pembroke Dockyard"}),
# (Q851348:Location {ID: "Q851348", name: "Cleddau River"}),
# (Q26:Location {ID: "Q26", name: "Northern Ireland"}),
# (Q937070:Location {ID: "Q937070", name: "Strangford loch"}),
# (Q166885:Location {ID: "Q166885", name: "Milford Haven Waterway"}),
# (Q7888194:Misc {ID: "Q7888194", name: "Brexit"}),
# (Q11706355:Misc {ID: "Q11706355", name: "Isle of Inishmore ferry"}),
# (Q52347656:Misc {ID: "Q52347656", name: "Blue Star 1"}),
# (Q16894987:Location {ID: "Q16894987", name: "Melin Bompren"}),
# (Q1954765:Organisation {ID: "Q1954765", name: "St Fagan's National Museum of History"}),
# (Q390036:Location {ID: "Q390036", name: "St Fagans"}),
# (Q5016882:Location {ID: "Q5016882", name: "Caerau Hillfort"}),
# (Q1127109:Organisation {ID: "Q1127109", name: "Silures tribe"}),
# (Q1035745:Organisation {ID: "Q1035745", name: "Cardiff University"}),
# (Q5016880:Location {ID: "Q5016880", name: "Caerau"}),
# (Q5368392:Location {ID: "Q5368392", name: "Ely"}),
# (Q1009261:Location {ID: "Q1009261", name: "Caerleon"}),
# (Q2844398:Location {ID: "Q2844398", name: "Caerleon Amphitheatre"}),
# (Q5179611:Location {ID: "Q5179611", name: "Cowbridge Grammar School"}),
# (Q7980559:Organisation {ID: "Q7980559", name: "2nd Battalion of the Welch Regiment"}),
# (Q5119940:Location {ID: "Q5119940", name: "Cilfynydd"}),
# (Q361:Misc {ID: "Q361", name: "World War One"}),
# (Q1024885:Location {ID: "Q1024885", name: "Llandrindod Wells"}),
# (Q7940945:Organisation {ID: "Q7940945", name: "VAD"}),
# (Q1045316:Location {ID: "Q1045316", name: "County Club hotel"}),
# (Q6905848:Organisation {ID: "Q6905848", name: "Montgomeryshire Yeomanry"}),
# (Q131329:Location {ID: "Q131329", name: "Arras"}),
# (Q23666:Misc {ID: "Q23666", name: "British"}),
# (Q2199408:Location {ID: "Q2199408", name: "Morval British Cemetery"}),
# (Q516446:Organisation {ID: "Q516446", name: "Royal Army Med Corps"}),
# (Q2536016:Location {ID: "Q2536016", name: "Crickhowell"}),
# (Q6661746:Location {ID: "Q6661746", name: "Llansamlet"}),
# (Q8338604:Organisation {ID: "Q8338604", name: "Second Devonshire Regiment"}),
# (Q3397684:Location {ID: "Q3397684", name: "Pontarddulais"}),
# (Q1537181:Location {ID: "Q1537181", name: "Tonypandy"}),
# (Q771986:Location {ID: "Q771986", name: "Chepstow"}),
# (Q752760:Organisation {ID: "Q752760", name: "Royal Welsh Fusiliers"}),
# (Q3098650:Organisation {ID: "Q3098650", name: "Royal Engineers"}),
# (Q152989:Location {ID: "Q152989", name: "Western Front"}),
# (Q52058336:Organisation {ID: "Q52058336", name: "Ocean Coal Company."}),
# (Q6964400:Location {ID: "Q6964400", name: "Nantymoel"}),
# (Q47516669:Organisation {ID: "Q47516669", name: "Sandfields Branch Library"}),
# (Q7416190:Location {ID: "Q7416190", name: "Sandfields"}),
# (Q119720093:Misc {ID: "Q119720093", name: "On the Road to St. Brides"}),
# (Q21462022:Person {ID: "Q21462022", name: "Parker Hagarty"}),
# (Q321465:Person {ID: "Q321465", name: "Thomas Barker"}),
# (Q119668867:Misc {ID: "Q119668867", name: "Storm at Night"}),
# (Q19921912:Person {ID: "Q19921912", name: "Frederick George Swaish"}),
# (Q119809447:Misc {ID: "Q119809447", name: "Country Lad"}),
# (Q119809446:Misc {ID: "Q119809446", name: "Puritan Soldier"}),
# (Q731056:Person {ID: "Q731056", name: "Sir James Jebusa Shannon"}),
# (Q113453623:Misc {ID: "Q113453623", name: "The Bathers"}),
# (Q23703471:Misc {ID: "Q23703471", name: "Kidwelly Castle"}),
# (Q1174087:Person {ID: "Q1174087", name: "David Cox"}),
# (Q428829:Location {ID: "Q428829", name: "Caernarfon"}),
# (Q85783095:Location {ID: "Q85783095", name: "National Eisteddfod Maes"}),
# (Q5498256:Person {ID: "Q5498256", name: "Frederick Lee Bridell"}),
# (Q7375001:Organisation {ID: "Q7375001", name: "Royal Welsh College of Music and Drama Arts Management"}),
# (Q3492283:Organisation {ID: "Q3492283", name: "South Wales Borderers"}),
# (Q7567789:Organisation {ID: "Q7567789", name: "South Lancs Regiment"}),
# (Q4879246:Organisation {ID: "Q4879246", name: "Bedfordshire Regt."}),
# (Q13948128:Organisation {ID: "Q13948128", name: "20th London Regt."}),
# (Q4115291:Organisation {ID: "Q4115291", name: "Northumberland Fusiliers"}),
# (Q6723656:Organisation {ID: "Q6723656", name: "Machine Gun Corps"}),
# (Q7374174:Organisation {ID: "Q7374174", name: "Royal Field Artillery"}),
# (Q2171029:Organisation {ID: "Q2171029", name: "Royal Garrison Artillery"}),
# (Q29504291:Location {ID: "Q29504291", name: "Penylan House"}),
# (Q10690:Location {ID: "Q10690", name: "Cardiff"}),
# (Q7987066:Location {ID: "Q7987066", name: "West of England"}),
# (Q336766:Person {ID: "Q336766", name: "Rabbi Sacks"}),
# (Q94920:Misc {ID: "Q94920", name: "Yom Tov"}),
# (Q5033865:Location {ID: "Q5033865", name: "Canton"}),
# (Q427792:Location {ID: "Q427792", name: "Penarth"}),
# (Q213154:Location {ID: "Q213154", name: "Aberystwyth"}),
# (Q6735137:Person {ID: "Q6735137", name: "Mai Jones"}),
# (Q3073748:Organisation {ID: "Q3073748", name: "Flint Town"}),
# (Q18662:Organisation {ID: "Q18662", name: "Cardiff City"}),
# (Q2532363:Location {ID: "Q2532363", name: "Presteigne"}),
# (Q13126874:Location {ID: "Q13126874", name: "Casgob"}),
# (Q360522:Person {ID: "Q360522", name: "Johnny Owens"}),
# (Q1364559:Location {ID: "Q1364559", name: "River Tawe"}),
# (Q7653665:Location {ID: "Q7653665", name: "Swansea canal"}),
# (Q20584616:Location {ID: "Q20584616", name: "Craig-y-Dinas"}),
# (Q1009284:Location {ID: "Q1009284", name: "Ystradfellte"}),
# (Q5277970:Location {ID: "Q5277970", name: "Dinas Rock"}),
# (Q43499:Person {ID: "Q43499", name: "Desiderius Erasmus"}),
# (Q160852:Person {ID: "Q160852", name: "William Gladstone"}),
# (Q19020085:Misc {ID: "Q19020085", name: "Colloquies"}),
# (Q101254:Location {ID: "Q101254", name: "Newport"}),
# (Q7837467:Location {ID: "Q7837467", name: "Tredegar House"}),
# (Q27839530:Person {ID: "Q27839530", name: "Morgan"}),
# (Q911673:Organisation {ID: "Q911673", name: "Longman Hurst Rees & Orme"}),
# (Q84:Location {ID: "Q84", name: "London"}),
# (Q493787:Location {ID: "Q493787", name: "Vicksburg"}),
# (Q1537:Location {ID: "Q1537", name: "Wisconsin"}),
# (Q56179591:Person {ID: "Q56179591", name: "Corporal John Griffith Jones"}),
# (Q7412048:Person {ID: "Q7412048", name: "S. Loxton"}),
# (Q32768:Misc {ID: "Q32768", name: "Anglo-Saxons"}),
# (Q21200:Misc {ID: "Q21200", name: "Germanic"}),
# (Q185103:Misc {ID: "Q185103", name: "Roman"}),
# (Q21:Location {ID: "Q21", name: "England"}),
# (Q42365:Misc {ID: "Q42365", name: "Old English"}),
# (Q1127343:Location {ID: "Q1127343", name: "Offa's Dyke"}),
# (Q94659677:Misc {ID: "Q94659677", name: "The Anglo-Saxon Chronicle"}),
# (Q59662686:Misc {ID: "Q59662686", name: "MS Cotton Tiberius Biv"}),
# (Q23308:Organisation {ID: "Q23308", name: "British Library"}),
# (Q2259532:Misc {ID: "Q2259532", name: "cleric"}),
# (Q12567:Misc {ID: "Q12567", name: "Viking"}),
# (Q15889630:Person {ID: "Q15889630", name: "Hroald"}),
# (Q19682:Location {ID: "Q19682", name: "Severn"}),
# (Q187114:Person {ID: "Q187114", name: "King Edward"}),
# (Q40403:Misc {ID: "Q40403", name: "jarls"}),
# (Q327:Location {ID: "Q327", name: "Brittany"}),
# (Q549761:Location {ID: "Q549761", name: "Warwick"}),
# (Q1892770:Location {ID: "Q1892770", name: "north Wales"}),
# (Q1860:Misc {ID: "Q1860", name: "English"}),
# (Q66736822:Misc {ID: "Q66736822", name: "The Anglo-Saxon Chronicle"}),
# (Q6106398:Organisation {ID: "Q6106398", name: "Dent, J. M."}),
# (Q6834717:Person {ID: "Q6834717", name: "Michael Swanton"}),
# (Q48434610:Person {ID: "Q48434610", name: "Professor John Hines"}),
# (Q5538902:Person {ID: "Q5538902", name: "George Edwards"}),
# (Q188353:Misc {ID: "Q188353", name: "Welsh Full International Football Shirt"}),
# (Q190978:Organisation {ID: "Q190978", name: "Northern Ireland"}),
# (Q180857:Organisation {ID: "Q180857", name: "Wales"}),
# (Q806549:Organisation {ID: "Q806549", name: "Bangor Football Club"}),
# (Q234178:Location {ID: "Q234178", name: "Bangor"}),
# (Q156990:Location {ID: "Q156990", name: "Monmouth"}),
# (Q2700922:Misc {ID: "Q2700922", name: "Chronometer, Watch and Clock Maker"}),
# (Q5167942:Misc {ID: "Q5167942", name: "Coopers"}),
# (Q15243879:Location {ID: "Q15243879", name: "Maindee"}),
# (Q35535:Organisation {ID: "Q35535", name: "police"}),
# (Q6456601:Misc {ID: "Q6456601", name: "Bangladeshi"}),
# (Q131491:Location {ID: "Q131491", name: "Brighton"}),
# (Q373342:Misc {ID: "Q373342", name: "Popular music"}),
# (Q752762:Location {ID: "Q752762", name: "Merthyr Tydfil"}),
# (Q1971174:Organisation {ID: "Q1971174", name: "University of South Wales"}),
# (Q159214:Misc {ID: "Q159214", name: "Smooth Lady's-mantle"}),
# (Q1762242:Location {ID: "Q1762242", name: "Pembroke"}),
# (Q6901018:Location {ID: "Q6901018", name: "52 Monkton"}),
# (Q55517968:Misc {ID: "Q55517968", name: "County Architect"}),
# (Q3400474:Location {ID: "Q3400474", name: "South Wales Valleys"}),
# (Q212238:Misc {ID: "Q212238", name: "Civil Servant"}),
# (Q1143242:Organisation {ID: "Q1143242", name: "The University of Glamorgan"}),
# (Q30995:Misc {ID: "Q30995", name: "Executive Secretary"}),
# (Q17986585:Organisation {ID: "Q17986585", name: "Coleg Y Cymoedd"}),
# (Q108380713:Organisation {ID: "Q108380713", name: "People's Collection Wales"}),
# (Q2020203:Location {ID: "Q2020203", name: "Rhyl"}),
# (Q104437580:Location {ID: "Q104437580", name: "Pier"}),
# (Q1585849:Location {ID: "Q1585849", name: "Kidwelly Castle"}),
# (Q835835:Location {ID: "Q835835", name: "Carmarthen"}),
# (Q12439:Location {ID: "Q12439", name: "Detroit"}),
# (Q1775183:Location {ID: "Q1775183", name: "Mich"}),
# (Q110280196:Organisation {ID: "Q110280196", name: "Detroit Photographic Company"}),
# (Q131454:Location {ID: "Q131454", name: "Library of Congress"}),
# (Q61:Location {ID: "Q61", name: "Washington, D.C."}),
# (Q30:Location {ID: "Q30", name: "USA"}),
# (Q66812256:Location {ID: "Q66812256", name: "Prints and Photographs Division"}),
# (Q1166:Location {ID: "Q1166", name: "Mich"}),
# (Q4667101:Location {ID: "Q4667101", name: "Aberglaslyn Pass"}),
# (Q257446:Location {ID: "Q257446", name: "Holyhead"}),
# (Q13128592:Person {ID: "Q13128592", name: "Gaenor Morgan Rees"}),
# (Q6818465:Organisation {ID: "Q6818465", name: "MyW"}),
# (Q3399436:Organisation {ID: "Q3399436", name: "Urdd"}),
# (Q124664360:Location {ID: "Q124664360", name: "Ty Glyn Aeron"}),
# (Q4970039:Organisation {ID: "Q4970039", name: "Heart Foundation"}),
# (Q32336584:Misc {ID: "Q32336584", name: "Y Wawr"}),
# (Q108398264:Location {ID: "Q108398264", name: "Conrah Hotel"}),
# (Q1162163:Misc {ID: "Q1162163", name: "Director"}),
# (Q106629792:Person {ID: "Q106629792", name: "Helgard Krause"}),
# (Q1432100:Organisation {ID: "Q1432100", name: "MyW"}),
# (Q217829:Location {ID: "Q217829", name: "Ceredigion"}),
# (Q3402099:Location {ID: "Q3402099", name: "Beulah"}),
# (Q63755054:Misc {ID: "Q63755054", name: "Building Contractor"}),
# (Q7352077:Organisation {ID: "Q7352077", name: "Robertson's"}),
# (Q428661:Misc {ID: "Q428661", name: "U-Boats"}),
# (Q3508104:Person {ID: "Q3508104", name: "TYRWHITT"}),
# (Q335013:Person {ID: "Q335013", name: "BEATTY"}),
# (Q55605019:Misc {ID: "Q55605019", name: "Battle Fleet"}),
# (Q2003342:Location {ID: "Q2003342", name: "Neath"}),
# (Q99625750:Person {ID: "Q99625750", name: "Dr Gethin Matthews"}),
# (Q1420500:Organisation {ID: "Q1420500", name: "Swansea University"}),
# (Q4666817:Location {ID: "Q4666817", name: "Cwmodyn quarry"}),
# (Q5173016:Location {ID: "Q5173016", name: "Upper Corris"}),
# (Q3406673:Location {ID: "Q3406673", name: "Ceinws"}),
# (Q29499929:Location {ID: "Q29499929", name: "Yr Efail"}),
# (Q1437242:Organisation {ID: "Q1437242", name: "Forestry Commission"}),
# (Q16007334:Location {ID: "Q16007334", name: "Brongest"}),
# (Q29484528:Organisation {ID: "Q29484528", name: "Salem Chapel"}),
# (Q47544271:Person {ID: "Q47544271", name: "Pelosi"}),
# (Q1952591:Location {ID: "Q1952591", name: "Mumbles"}),
# (Q497612:Person {ID: "Q497612", name: "Paulette"}),
# (Q15930574:Person {ID: "Q15930574", name: "Brian"}),
# (Q1672043:Organisation {ID: "Q1672043", name: "Iona Community"}),
# (Q22:Location {ID: "Q22", name: "Scotland"}),
# (Q6729228:Location {ID: "Q6729228", name: "Maenclochog"}),
# (Q792453:Person {ID: "Q792453", name: "Bella"}),
# (Q19962582:Person {ID: "Q19962582", name: "Beau"}),
# (Q918396:Organisation {ID: "Q918396", name: "NHS"}),
# (Q145:Location {ID: "Q145", name: "United Kingdom"}),
# (Q56174671:Organisation {ID: "Q56174671", name: "CND Cymru"}),
# (Q178511:Organisation {ID: "Q178511", name: "Campaign for Nuclear Disarmament"}),
# (Q124830627:Location {ID: "Q124830627", name: "Bridgend Bunker"}),
# (Q102728:Location {ID: "Q102728", name: "Ypres"}),
# (Q1215200:Person {ID: "Q1215200", name: "White"}),
# (Q31:Location {ID: "Q31", name: "Belgium"}),
# (Q14201393:Location {ID: "Q14201393", name: "Northern France"}),
# (Q2273077:Location {ID: "Q2273077", name: "Newcastle Emlyn"}),
# (Q87866152:Misc {ID: "Q87866152", name: "lockdown"}),
# (Q3401133:Location {ID: "Q3401133", name: "Bagillt"}),
# (Q223625:Misc {ID: "Q223625", name: "lockdown"}),
# (Q505610:Location {ID: "Q505610", name: "Flintshire"}),
# (Q1883524:Location {ID: "Q1883524", name: "Bethesda"}),
# (Q81068910:Misc {ID: "Q81068910", name: "coronavirus pandemic"}),
# (Q171923:Location {ID: "Q171923", name: "Bala"}),
# (Q13128783:Person {ID: "Q13128783", name: "Gruffudd Parry"}),
# (Q3395446:Person {ID: "Q3395446", name: "Daniel Owen"}),
# (Q746681:Location {ID: "Q746681", name: "Egham"}),
# (Q1202039:Location {ID: "Q1202039", name: "Royal Holloway College"}),
# (Q756819:Location {ID: "Q756819", name: "Strand"}),
# (Q84263196:Misc {ID: "Q84263196", name: "COVID 19"}),
# (Q2046319:Organisation {ID: "Q2046319", name: "Amgueddfa Cymru"}),
# (Q5623809:Person {ID: "Q5623809", name: "Dr Gwyn Thomas"}),
# (Q77177612:Misc {ID: "Q77177612", name: "Amser Dyn, Sef Darnau o Einioes"}),
# (Q504796:Misc {ID: "Q504796", name: "Triggerfish"}),
# (Q8001329:Organisation {ID: "Q8001329", name: "Wildlife Trust of South and West Wales"}),
# (Q7114024:Location {ID: "Q7114024", name: "Overton"}),
# (Q101553389:Misc {ID: "Q101553389", name: "Wicipics"}),
# (Q14946043:Misc {ID: "Q14946043", name: "CC BY-SA 3.0 Licence"}),
# (Q43449:Organisation {ID: "Q43449", name: "Creative Commons"}),
# (Q15700834:Misc {ID: "Q15700834", name: "Grade II listed"}),
# (Q109128:Location {ID: "Q109128", name: "Gwynedd"}),
# (Q93191:Misc {ID: "Q93191", name: "Baptist"}),
# (Q1765460:Location {ID: "Q1765460", name: "Aberaeron"}),
# (Q29488630:Location {ID: "Q29488630", name: "No.14 Albert Street"}),
# (Q29488648:Location {ID: "Q29488648", name: "No.5 Bridge Street (J.R.Evans & Co.)"}),
# (Q29488672:Location {ID: "Q29488672", name: "No.3 Greenland Terrace (Delfryn)"}),
# (Q29488726:Location {ID: "Q29488726", name: "No.22 North Road"}),
# (Q180:Organisation {ID: "Q180", name: "Wikimedia"}),
# (Q29502328:Location {ID: "Q29502328", name: "19 Chapel Street"}),
# (Q26336716:Location {ID: "Q26336716", name: "19, Chapel Street"}),
# (Q29496408:Location {ID: "Q29496408", name: "Tabernacl Chapel"}),
# (Q817971:Location {ID: "Q817971", name: "Conwy"}),
# (Q5024548:Misc {ID: "Q5024548", name: "Calvinistic Methodist"}),
# (Q5730951:Location {ID: "Q5730951", name: "Henryd"}),
# (Q7837752:Location {ID: "Q7837752", name: "Tref Alaw"}),
# (Q20713291:Location {ID: "Q20713291", name: "Bethania Welsh Independent Chapel"}),
# (Q5131038:Location {ID: "Q5131038", name: "Cleddau Bridge"}),
# (Q50758813:Location {ID: "Q50758813", name: "Sardis chapel"}),
# (Q5050344:Location {ID: "Q5050344", name: "Castle An Dinas"}),
# (Q105814190:Location {ID: "Q105814190", name: "St. Ives Harbour"}),
# (Q15260955:Location {ID: "Q15260955", name: "Nanjizal Bay"}),
# (Q1431121:Location {ID: "Q1431121", name: "St. Michaels Mount"}),
# (Q654239:Location {ID: "Q654239", name: "Sennen Cove"}),
# (Q5043749:Location {ID: "Q5043749", name: "Cart Brea"}),
# (Q15248133:Location {ID: "Q15248133", name: "Market House"}),
# (Q2560214:Location {ID: "Q2560214", name: "Caistor"}),
# (Q17744311:Location {ID: "Q17744311", name: "St Dingats Church"}),
# (Q3402398:Location {ID: "Q3402398", name: "New Tredegar"}),
# (Q56186976:Location {ID: "Q56186976", name: "Brithdir Chapel"}),
# (Q183551:Location {ID: "Q183551", name: "Waterford"}),
# (Q36647:Location {ID: "Q36647", name: "Cork"}),
# (Q1018730:Location {ID: "Q1018730", name: "Fishguard"}),
# (Q37100:Location {ID: "Q37100", name: "New Zealand"}),
# (Q81392381:Location {ID: "Q81392381", name: "Porthkerry Park"}),
# (Q809009:Location {ID: "Q809009", name: "Barry"}),
# (Q2981060:Location {ID: "Q2981060", name: "Coal Exchange"}),
# (Q11698324:Location {ID: "Q11698324", name: "Paternoster Street"}),
# (Q1570610:Location {ID: "Q1570610", name: "Beaver Dam"}),
# (Q7131919:Location {ID: "Q7131919", name: "Pantperthog"}),
# (Q4093:Location {ID: "Q4093", name: "Glasgow"}),
# (Q1141148:Location {ID: "Q1141148", name: "Gower Peninsula"}),
# (Q102081829:Location {ID: "Q102081829", name: "Ystumtuen Lead Mine"}),
# (Q17743386:Location {ID: "Q17743386", name: "No.1 Portland Place (portland House)"}),
# (Q2735955:Location {ID: "Q2735955", name: "Heath High Level railway station"}),
# (Q29483723:Location {ID: "Q29483723", name: "Neuadd Dyfrdwy (Normal College) College Road"}),
# (Q29483815:Location {ID: "Q29483815", name: "Tŵr-Gwyn Chapel"}),
# (Q104804861:Location {ID: "Q104804861", name: "Roath Conservative Club"}),
# (Q1529978:Location {ID: "Q1529978", name: "Tredegar"}),
# (Q29502554:Location {ID: "Q29502554", name: "Church of Saint Brynach"}),
# (Q6661117:Location {ID: "Q6661117", name: "Llanboidy"}),
# (Q33158029:Location {ID: "Q33158029", name: "Central Hotel"}),
# (Q6661685:Location {ID: "Q6661685", name: "Llanon"}),
# (Q168159:Location {ID: "Q168159", name: "Anglesey"}),
# (Q20826063:Misc {ID: "Q20826063", name: "Cornish Gorsedd"}),
# (Q2720261:Location {ID: "Q2720261", name: "Ystradgynlais"}),
# (Q909119:Location {ID: "Q909119", name: "Caerphilly"}),
# (Q34997882:Person {ID: "Q34997882", name: "Cyril"}),
# (Q58819597:Organisation {ID: "Q58819597", name: "Extinction Rebellion"}),
# (Q99448672:Location {ID: "Q99448672", name: "Brongest"}),
# (Q3405876:Organisation {ID: "Q3405876", name: "Welsh Books Council"}),
# (Q3504712:Person {ID: "Q3504712", name: "Francis Bedford"}),
# (Q37316014:Person {ID: "Q37316014", name: "Vanderberg"}),
# (Q12892:Location {ID: "Q12892", name: "Antwerp"}),
# (Q207380:Person {ID: "Q207380", name: "Isambard Kingdom Brunel"}),
# (Q2363258:Person {ID: "Q2363258", name: "Sir Richard Hoare"}),
# (Q202305:Misc {ID: "Q202305", name: "Crowberry"}),
# (Q13376892:Person {ID: "Q13376892", name: "Helen"}),
# (Q78864866:Misc {ID: "Q78864866", name: "Martin Ridley Collection"}),
# (Q234178)-[:location_in]-> (Q109128),
# (Q42365)-[:depicts]-> (Q94659677),
# (Q1127109)-[:work_location]-> (Q25),
# (Q81068910)-[:location]-> (Q1883524),
# (Q835835)-[:location_in]-> (Q25),
# (Q48434610)-[:member_of]-> (Q1035745),
# (Q66736822)-[:depicts]-> (Q549761),
# (Q185103)-[:operating_area]-> (Q21),
# (Q119720093)-[:depicts]-> (Q21462022),
# (Q29502328)-[:location_in]-> (Q996492),
# (Q13128783)-[:participant_in]-> (Q670265),
# (Q66812256)-[:location_in]-> (Q30),
# (Q5413890)-[:work_location]-> (Q208209),
# (Q1775183)-[:location_in]-> (Q12439),
# (Q3508104)-[:participant_in]-> (Q428661),
# (Q6834717)-[:notable_work]-> (Q42365),
# (Q131454)-[:location_in]-> (Q66812256),
# (Q97581503)-[:place_of_birth]-> (Q23156),
# (Q29499929)-[:location_in]-> (Q3406673),
# (Q42365)-[:location]-> (Q327),
# (Q497612)-[:significant_person]-> (Q47544271),
# (Q85783095)-[:location_in]-> (Q428829),
# (Q670265)-[:depicts]-> (Q3395446),
# (Q549761)-[:location_in]-> (Q327),
# (Q20594046)-[:location]-> (Q881062),
# (Q187114)-[:affiliation]-> (Q6106398),
# (Q131454)-[:location_in]-> (Q61),
# (Q66736822)-[:location]-> (Q25),
# (Q59662686)-[:depicts]-> (Q94659677),
# (Q26515392)-[:location_in]-> (Q208209),
# (Q94659677)-[:depicts]-> (Q59662686),
# (Q1215200)-[:member_of]-> (Q7980559),
# (Q29488630)-[:location_in]-> (Q1765460),
# (Q15889630)-[:work_location]-> (Q327),
# (Q29484528)-[:work_location]-> (Q99448672),
# (Q187114)-[:significant_person]-> (Q15889630),
# (Q48434610)-[:work_location]-> (Q25),
# (Q373342)-[:location]-> (Q752762),
# (Q116874592)-[:location_in]-> (Q5043749),
# (Q48434610)-[:participant_in]-> (Q1860),
# (Q428661)-[:depicts]-> (Q3508104),
# (Q5016882)-[:location_in]-> (Q25),
# (Q19921912)-[:participant_in]-> (Q119809447),
# (Q188353)-[:depicts]-> (Q5538902),
# (Q428829)-[:location_in]-> (Q85783095),
# (Q33959)-[:location_in]-> (Q142),
# (Q29483815)-[:location_in]-> (Q234178),
# (Q42365)-[:location]-> (Q19682),
# (Q918396)-[:work_location]-> (Q25),
# (Q33158029)-[:location_in]-> (Q213154),
# (Q66736822)-[:location]-> (Q19682),
# (Q792453)-[:significant_person]-> (Q19962582),
# (Q106629792)-[:occupation]-> (Q1162163),
# (Q42365)-[:location]-> (Q25),
# (Q2745177)-[:location]-> (Q207176),
# (Q2745177)-[:location]-> (Q996492),
# (Q124664360)-[:location_in]-> (Q1286223),
# (Q5016882)-[:location_in]-> (Q1286223),
# (Q29488726)-[:location_in]-> (Q1765460),
# (Q654239)-[:location_in]-> (Q23148),
# (Q7980559)-[:work_location]-> (Q31),
# (Q183551)-[:location_in]-> (Q22890),
# (Q1672043)-[:work_location]-> (Q4093),
# (Q2046319)-[:affiliation]-> (Q2046319),
# (Q19020085)-[:depicts]-> (Q43499),
# (Q1174087)-[:notable_work]-> (Q23703471),
# (Q918396)-[:work_location]-> (Q145),
# (Q7980559)-[:participant_in]-> (Q361),
# (Q106629792)-[:affiliation]-> (Q3405876),
# (Q5173016)-[:location_in]-> (Q4666817),
# (Q56186976)-[:location_in]-> (Q3402398),
# (Q66362702)-[:location_in]-> (Q2003342),
# (Q1431121)-[:location_in]-> (Q208209),
# (Q361)-[:depicts]-> (Q52058336),
# (Q7837752)-[:location_in]-> (Q168159),
# (Q1025780)-[:location_in]-> (Q26596711),
# (Q110280196)-[:work_location]-> (Q12439),
# (Q209055)-[:location_in]-> (Q23156),
# (Q7940945)-[:affiliation]-> (Q7940945),
# (Q335013)-[:participant_in]-> (Q55605019),
# (Q187114)-[:work_location]-> (Q1892770),
# (Q6106398)-[:notable_work]-> (Q66736822),
# (Q17986585)-[:affiliation]-> (Q108380713),
# (Q15700834)-[:location]-> (Q109128),
# (Q1954765)-[:location_in]-> (Q390036),
# (Q2745177)-[:operating_area]-> (Q171923),
# (Q15889630)-[:residence]-> (Q19682),
# (Q81068910)-[:depicts]-> (Q87866152),
# (Q66736822)-[:depicts]-> (Q15889630),
# (Q7940945)-[:work_location]-> (Q1024885),
# (Q1166)-[:location_in]-> (Q12439),
# (Q29488648)-[:location_in]-> (Q1765460),
# (Q1585849)-[:location_in]-> (Q25),
# (Q42365)-[:operating_area]-> (Q25),
# (Q40403)-[:depicts]-> (Q42365),
# (Q6834717)-[:significant_person]-> (Q48434610),
# (Q104395394)-[:participant_in]-> (Q100164652),
# (Q5024548)-[:operating_area]-> (Q817971),
# (Q17644344)-[:depicts]-> (Q5617932),
# (Q1162163)-[:depicts]-> (Q106629792),
# (Q21200)-[:depicts]-> (Q32768),
# (Q5730951)-[:location_in]-> (Q817971),
# (Q1143242)-[:notable_work]-> (Q212238),
# (Q26596711)-[:location_in]-> (Q1025780),
# (Q3399436)-[:participant_in]-> (Q2745177),
# (Q42365)-[:depicts]-> (Q1127343),
# (Q2199408)-[:location_in]-> (Q142),
# (Q42365)-[:depicts]-> (Q40403),
# (Q2259532)-[:depicts]-> (Q12567),
# (Q752760)-[:work_location]-> (Q1537181),
# (Q4667101)-[:location_in]-> (Q25),
# (Q61)-[:location_in]-> (Q30),
# (Q5538902)-[:notable_work]-> (Q188353),
# (Q1860)-[:depicts]-> (Q15889630),
# (Q15889630)-[:participant_in]-> (Q40403),
# (Q1860)-[:depicts]-> (Q40403),
# (Q66736822)-[:depicts]-> (Q40403),
# (Q37316014)-[:residence]-> (Q12892),
# (Q223625)-[:location]-> (Q505610),
# (Q187114)-[:work_location]-> (Q19682),
# (Q8338604)-[:work_location]-> (Q3397684),
# (Q56179591)-[:residence]-> (Q493787),
# (Q15889630)-[:work_location]-> (Q549761),
# (Q80338)-[:location_in]-> (Q668),
# (Q35535)-[:work_location]-> (Q15243879),
# (Q1035745)-[:affiliation]-> (Q6106398),
# (Q549761)-[:location_in]-> (Q19682),
# (Q47544271)-[:significant_person]-> (Q47544271),
# (Q336766)-[:participant_in]-> (Q94920),
# (Q5050344)-[:location_in]-> (Q208209),
# (Q7980559)-[:work_location]-> (Q5119940),
# (Q101254)-[:location_in]-> (Q25),
# (Q32768)-[:operating_area]-> (Q21),
# (Q1892770)-[:location_in]-> (Q549761),
# (Q113453623)-[:depicts]-> (Q731056),
# (Q223625)-[:location]-> (Q3401133),
# (Q19921912)-[:occupation]-> (Q119809446),
# (Q6106398)-[:work_location]-> (Q84),
# (Q327)-[:location_in]-> (Q549761),
# (Q1860)-[:depicts]-> (Q42365),
# (Q26336716)-[:location_in]-> (Q996492),
# (Q1348)-[:location_in]-> (Q80338),
# (Q99625750)-[:affiliation]-> (Q1420500),
# (Q670265)-[:depicts]-> (Q13128783),
# (Q497612)-[:significant_person]-> (Q497612),
# (Q21200)-[:location]-> (Q21),
# (Q911673)-[:work_location]-> (Q84),
# (Q37100)-[:location_in]-> (Q37100),
# (Q7131919)-[:location_in]-> (Q675460),
# (Q87866152)-[:location]-> (Q25),
# (Q1765460)-[:location_in]-> (Q29488648),
# (Q101254)-[:location_in]-> (Q145),
# (Q1860)-[:depicts]-> (Q549761),
# (Q996492)-[:location_in]-> (Q29502328),
# (Q11706355)-[:depicts]-> (Q52347656),
# (Q40403)-[:operating_area]-> (Q19682),
# (Q40403)-[:depicts]-> (Q15889630),
# (Q20713291)-[:location_in]-> (Q7837752),
# (Q58819597)-[:work_location]-> (Q10690),
# (Q12439)-[:location_in]-> (Q1166),
# (Q2745177)-[:location]-> (Q990103),
# (Q217829)-[:location_in]-> (Q3402099),
# (Q4666817)-[:location_in]-> (Q5173016),
# (Q119809447)-[:depicts]-> (Q19921912),
# (Q40403)-[:location]-> (Q327),
# (Q48434610)-[:affiliation]-> (Q6106398),
# (Q24662603)-[:location_in]-> (Q104822257),
# (Q6456601)-[:location]-> (Q131491),
# (Q108380713)-[:affiliation]-> (Q17986585),
# (Q222595)-[:work_location]-> (Q668),
# (Q47544271)-[:significant_person]-> (Q497612),
# (Q23703471)-[:depicts]-> (Q1174087),
# (Q13128783)-[:notable_work]-> (Q670265),
# (Q1202039)-[:location_in]-> (Q746681),
# (Q180857)-[:affiliation]-> (Q190978),
# (Q15889630)-[:residence]-> (Q327),
# (Q110280196)-[:work_location]-> (Q1166),
# (Q2745177)-[:location]-> (Q669171),
# (Q4666817)-[:location_in]-> (Q4666817),
# (Q22677638)-[:location]-> (Q496368),
# (Q37316014)-[:affiliation]-> (Q29484528),
# (Q18662)-[:affiliation]-> (Q3073748),
# (Q25)-[:location_in]-> (Q145),
# (Q21462022)-[:participant_in]-> (Q119720093),
# (Q12439)-[:location_in]-> (Q1775183),
# (Q100164652)-[:depicts]-> (Q104395394),
# (Q1215200)-[:affiliation]-> (Q7980559),
# (Q937070)-[:location_in]-> (Q26),
# (Q5016882)-[:location_in]-> (Q5016880),
# (Q5623809)-[:notable_work]-> (Q77177612),
# (Q40403)-[:depicts]-> (Q1860),
# (Q1892770)-[:location_in]-> (Q19682),
# (Q32336584)-[:location]-> (Q108398264),
# (Q756819)-[:location_in]-> (Q84),
# (Q1045316)-[:location_in]-> (Q1024885),
# (Q360724)-[:affiliation]-> (Q16998883),
# (Q104437580)-[:location_in]-> (Q25),
# (Q2745177)-[:location]-> (Q748065),
# (Q66812256)-[:location_in]-> (Q61),
# (Q996492)-[:location_in]-> (Q26336716),
# (Q6834717)-[:participant_in]-> (Q66736822),
# (Q5277970)-[:location_in]-> (Q1009284),
# (Q43449)-[:notable_work]-> (Q14946043),
# (Q3406673)-[:location_in]-> (Q3406673),
# (Q40403)-[:location]-> (Q549761),
# (Q15260955)-[:location_in]-> (Q23148),
# (Q17744311)-[:location_in]-> (Q3402398),
# (Q3098650)-[:affiliation]-> (Q752760),
# (Q29492351)-[:location_in]-> (Q2273077),
# (Q87866152)-[:depicts]-> (Q81068910),
# (Q1348)-[:location_in]-> (Q668),
# (Q93191)-[:operating_area]-> (Q234178),
# (Q29496408)-[:location_in]-> (Q5730951),
# (Q8001329)-[:work_location]-> (Q7114024),
# (Q3073748)-[:affiliation]-> (Q18662),
# (Q3401133)-[:location_in]-> (Q505610),
# (Q42365)-[:location]-> (Q21),
# (Q15889630)-[:participant_in]-> (Q1860),
# (Q208209)-[:location_in]-> (Q13443285),
# (Q1035745)-[:participant_in]-> (Q42365),
# (Q36647)-[:location_in]-> (Q22890),
# (Q75960697)-[:work_location]-> (Q836),
# (Q97581503)-[:place_of_birth]-> (Q209055),
# (Q81068910)-[:operating_area]-> (Q25),
# (Q15889630)-[:significant_person]-> (Q187114),
# (Q119668867)-[:depicts]-> (Q321465),
# (Q752760)-[:affiliation]-> (Q3098650),
# (Q187114)-[:participant_in]-> (Q40403),
# (Q652930)-[:location_in]-> (Q89035834),
# (Q78864866)-[:depicts]-> (Q1286223),
# (Q15930574)-[:significant_person]-> (Q15930574),
# (Q2146298)-[:location_in]-> (Q208209),
# (Q13126874)-[:location_in]-> (Q2532363),
# (Q40403)-[:operating_area]-> (Q327),
# (Q6834717)-[:participant_in]-> (Q1860),
# (Q1018730)-[:location_in]-> (Q784824),
# (Q11698324)-[:location_in]-> (Q84),
# (Q32768)-[:depicts]-> (Q21200),
# (Q104804861)-[:location_in]-> (Q1529978),
# (Q15700834)-[:location]-> (Q234178),
# (Q131329)-[:location_in]-> (Q142),
# (Q2745177)-[:depicts]-> (Q3399436),
# (Q119809446)-[:depicts]-> (Q19921912),
# (Q87866152)-[:operating_area]-> (Q3401133),
# (Q116887767)-[:location_in]-> (Q208209),
# (Q48434610)-[:participant_in]-> (Q42365),
# (Q81068910)-[:operating_area]-> (Q1892770),
# (Q29504291)-[:location_in]-> (Q10690),
# (Q207380)-[:notable_work]-> (Q843251),
# (Q19962582)-[:significant_person]-> (Q792453),
# (Q40403)-[:depicts]-> (Q1892770),
# (Q779603)-[:location_in]-> (Q23090),
# (Q7888194)-[:depicts]-> (Q11706355),
# (Q5024548)-[:operating_area]-> (Q5730951),
# (Q94659677)-[:depicts]-> (Q1127343),
# (Q2560214)-[:location_in]-> (Q23090),
# (Q77177612)-[:location]-> (Q234178),
# (Q12567)-[:operating_area]-> (Q25),
# (Q25)-[:location_in]-> (Q4667101),
# (Q40403)-[:operating_area]-> (Q25),
# (Q29502554)-[:location_in]-> (Q6661117),
# (Q2735955)-[:location_in]-> (Q10690),
# (Q1860)-[:location]-> (Q25),
# (Q29483723)-[:location_in]-> (Q234178),
# (Q6834717)-[:affiliation]-> (Q6106398),
# (Q670265)-[:location]-> (Q1428848),
# (Q1860)-[:location]-> (Q327),
# (Q16894987)-[:location_in]-> (Q390036),
# (Q94659677)-[:depicts]-> (Q42365),
# (Q2745177)-[:depicts]-> (Q2745177),
# (Q19682)-[:location_in]-> (Q1892770),
# (Q4039563)-[:work_location]-> (Q16897354),
# (Q1585849)-[:location_in]-> (Q835835),
# (Q77177612)-[:depicts]-> (Q77177612),
# (Q180)-[:affiliation]-> (Q180),
# (Q361)-[:depicts]-> (Q7980559),
# (Q321465)-[:notable_work]-> (Q119668867),
# (Q1570610)-[:location_in]-> (Q1537),
# (Q327)-[:location_in]-> (Q19682),
# (Q1765460)-[:location_in]-> (Q29488630),
# (Q13128592)-[:affiliation]-> (Q6818465),
# (Q131454)-[:location_in]-> (Q30),
# (Q19020085)-[:depicts]-> (Q160852),
# (Q208209)-[:location_in]-> (Q116887767),
# (Q40403)-[:depicts]-> (Q187114),
# (Q15889630)-[:participant_in]-> (Q42365),
# (Q102081829)-[:location_in]-> (Q217829),
# (Q23666)-[:location]-> (Q2199408),
# (Q17743386)-[:location_in]-> (Q1765460),
# (Q6106398)-[:affiliation]-> (Q1035745),
# (Q15889630)-[:affiliation]-> (Q6106398),
# (Q16894987)-[:location_in]-> (Q1954765),
# (Q1035745)-[:participant_in]-> (Q1860),
# (Q6901018)-[:location_in]-> (Q1762242),
# (Q2981060)-[:location_in]-> (Q10690),
# (Q43499)-[:notable_work]-> (Q19020085),
# (Q7837752)-[:location_in]-> (Q20713291),
# (Q7987066)-[:location_in]-> (Q29504291),
# (Q81392381)-[:location_in]-> (Q809009),
# (Q59662686)-[:depicts]-> (Q42365),
# (Q1860)-[:location]-> (Q19682),
# (Q3406673)-[:location_in]-> (Q29499929),
# (Q15889630)-[:participant_in]-> (Q66736822),
# (Q1765460)-[:location_in]-> (Q29488672),
# (Q1127109)-[:work_location]-> (Q5016882),
# (Q43499)-[:significant_person]-> (Q160852),
# (Q4093)-[:location_in]-> (Q22),
# (Q59662686)-[:depicts]-> (Q1127343),
# (Q55517968)-[:location]-> (Q6901018),
# (Q101553389)-[:depicts]-> (Q14946043),
# (Q2020203)-[:location_in]-> (Q25),
# (Q2046319)-[:participant_in]-> (Q87866152),
# (Q1892770)-[:location_in]-> (Q327),
# (Q7980559)-[:significant_person]-> (Q1215200),
# (Q29496408)-[:location_in]-> (Q817971),
# (Q3402099)-[:location_in]-> (Q217829),
# (Q1883524)-[:location_in]-> (Q1892770),
# (Q6661685)-[:location_in]-> (Q25),
# (Q1143242)-[:notable_work]-> (Q30995),
# (Q1765460)-[:location_in]-> (Q29488726),
# (Q25)-[:location_in]-> (Q835835),
# (Q731056)-[:participant_in]-> (Q113453623),
# (Q40403)-[:depicts]-> (Q66736822),
# (Q7812993)-[:location_in]-> (Q23090),
# (Q59662686)-[:depicts]-> (Q23308),
# (Q42365)-[:location]-> (Q549761),
# (Q40403)-[:location]-> (Q19682),
# (Q918396)-[:participant_in]-> (Q81068910),
# (Q104437580)-[:location_in]-> (Q2020203),
# (Q66736822)-[:depicts]-> (Q42365),
# (Q1762242)-[:location_in]-> (Q6901018),
# (Q7902126)-[:location_in]-> (Q23090),
# (Q42365)-[:depicts]-> (Q48434610),
# (Q52058336)-[:participant_in]-> (Q361),
# (Q110280196)-[:work_location]-> (Q1775183),
# (Q6834717)-[:affiliation]-> (Q1035745),
# (Q29488672)-[:location_in]-> (Q1765460),
# (Q1860)-[:depicts]-> (Q66736822),
# (Q7837467)-[:location_in]-> (Q101254),
# (Q190978)-[:affiliation]-> (Q180857),
# (Q66812256)-[:location_in]-> (Q131454),
# (Q2745177)-[:location]-> (Q1186888),
# (Q7980559)-[:work_location]-> (Q14201393),
# (Q178511)-[:affiliation]-> (Q178511),
# (Q30524253)-[:location_in]-> (Q213154),
# (Q1672043)-[:work_location]-> (Q22),
# (Q5016882)-[:location_in]-> (Q5368392),
